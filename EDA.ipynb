# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# After Cleaning the Raw Data, we will save the file as .csv. Now its time to plot beautiful graphs on the data avaliable, where a user can easily understand the features and the elements which belongs to a specific brand of product.

# %%
df = pd.read_csv('mobiles_info.csv')

# %%
df
# Out:
#         Brand         Version               Color   Cost  RealCost  \
# 0     SAMSUNG          T3 Pro               Black  11499     20999
# 1       Nokia  105 Single SIM               Black   1181      1399
# 2           I          T3 Pro               Black   1699      2199
# 3    Motorola          T3 Pro      Brilliant Blue  12999     14999
# 4    Motorola          T3 Pro         Olive Green  17999     20999
# ..        ...             ...                 ...    ...       ...
# 451  Motorola          T3 Pro    Marshmallow Blue  22999     25999
# 452      POCO             C61  Diamond Dust Black   5799      8999
# 453     REDMI             13C     Starfrost White   7199     11999
# 454     REDMI          T3 Pro     Starlight Black  13258     17999
# 455      POCO          T3 Pro      Galactic Black   7999     11999
#
#      StarReview  Rating  Reviews  RAM (GB)  ROM (GB)  DisplaySize (cm)
# 0           4.2   49567   2279.0     6.000   128.000             16.76
# ...

# %%
df.dtypes
# Out:
# Brand                object
# Version              object
# Color                object
# Cost                  int64
# RealCost              int64
# StarReview          float64
# Rating                int64
# Reviews             float64
# RAM (GB)            float64
# ROM (GB)            float64
# DisplaySize (cm)    float64
# dtype: object

# %% [markdown]
# PROBLEM STATEMENT:
#
# The aim of this project is to build a robust data scraping pipeline to extract, clean, and analyze data on mobile phones from Flipkart. With rapid changes in the mobile phone industry, consumers are increasingly seeking comprehensive information on product features, pricing trends, and user satisfaction to make informed purchase decisions
#
# This project will involve scraping details such as brand, model, price, key specifications (RAM, storage, camera quality, battery capacity, etc.), user ratings, and customer reviews. The data will be processed to create a structured Data Frame suitable for further analysis.
#
# OBJECTIES:
#
# -> Data Collection:  Scrape data on mobile phones, including specifications, prices, ratings, and reviews, to build a comprehensive dtaset.
#
# -> Data Cleaning:  Standardize and clean the data to ensure consistency, handling missing values and formattin issues.
#
# -> Data Analysis & Visulization:
#
#    a. Pricing Trends:  Analyze price variations across different brands and models.
#    b. Customer Sentiment: Conduct sentiment analysis on customer reviews to understand user satisfaction and identify common concerns.
#    c. Feature Popularity: Explore trends in key features like RAM size, storage options, and camera quality based on customer preferences.
#    d. Rating Analysis: Correlate product specifications and pricing with user ratings to find patterns in customr satisfaction.
#
# -> Insights Generation:  Generate actionable insights, such as identifying popular brands, the most sought-after features, and budget ranges that attract the highest custion.
# this is my PS

# %% [markdown]
# I have seperated the different data typed columns into a list, just to understand what is data type of a specific column in the dataset.

# %%
## In my dataset there are three different data typed values. Float, Int (numerical) and Object (categorical)
float_columns = ['StarReview', 'Reviews', 'RAM (GB)', 'ROM (GB)', 'DisplaySize (cm)']
int_columns = ['Cost', 'RealCost', 'Rating']
object_columns = ['Brand', 'Version', 'Color']

# %% [markdown]
# Here i am plotting Univariate Analysis.
# Univariate Analysis includes several types of Graphs to plot.
#
# 01. Column Name: StarReview
#     Type of Graph: Box Plot
#     Description: The individuals who can buy mobiles, will give a stars based on the performance of the product. The highest star is 5 and here we have                   different star reviews on each mobile.
#                  The line in the middle of a box plot represents the median of the data. The median is the middle value of a dataset when it is arranged                  in ascending order. It divides the data into two equal halves:
#                  --> 50% of the data points lie below the median.
#                  --> 50% of the data points lie above the median.

# %%
## Box plot for StarReview
plt.figure(figsize=(5,3))
sns.boxplot(data=df, x='StarReview', palette='husl')
plt.title("Box Plot for StarReview", fontsize=12)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5680\1145187427.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='StarReview', palette='husl')

# %% [markdown]
# 02. Column Name: Reviews,
#     Type of Graph: Violin Plot,
#     Description: This columns gives the information about the number of people given their own reviews after verifying the performance of the specific                    brand of the mobile. In the graph, we can see there are the reviews mostly in between 2000-3000.

# %%
# Violin plot for Reviews
plt.figure(figsize=(5,3)) 
sns.violinplot(data=df, x='Reviews', palette='muted')
plt.title("Violin Plot for Reviews", fontsize=12)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5416\4263066918.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Reviews', palette='muted')

# %% [markdown]
# 03. Column Name: RAM (GB),
#     Tyoe of Graph: Histogram
#     Description: It is used to represent the distribution of eacg numerical data. The line which is passing through every bar is called frequency                         polygon. It connects the midpoints of each bar, providing a smooth representation of the data's frequency distribution, making it                        easier to visualize trends and patterns. We can see the count of people using the different type of GB's. Most of them are using 8GB.

# %%
# Histogram for RAM (GB)
plt.figure(figsize=(5,3))
sns.histplot(data=df, x='RAM (GB)', kde=True, color='green', bins=20)
plt.title("Histogram for RAM (GB)", fontsize=12)
plt.show()

# %% [markdown]
# 04. Column Name: ROM (GB),
#     Type of Graph: Histogram
#     Description: As we see in the graph of the people are using the mobiles which have the ROM storage in between 100-150 (GB).

# %%
plt.figure(figsize=(5,3))
sns.histplot(data=df, x='ROM (GB)', kde=True, color='orange', bins=20)
plt.title("Histogram for ROM (GB)", fontsize=12)
plt.show()

# %% [markdown]
# 05. Column Name: DisplaySize (cm),
#     Type of Graph: Violin
#     Interpretation: The mobiles which are under use of the user are mostly having the screen size of 17 (cm). We can find different sizes too, but the                       most number of people are using big screens.

# %%
plt.figure(figsize=(5,3)) 
sns.violinplot(data=df, x='DisplaySize (cm)', palette='muted')
plt.title("Violin Plot for DisplaySize (cm)", fontsize=12)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5416\2851867985.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='DisplaySize (cm)', palette='muted')

# %% [markdown]
# 06. Column Name: RealCost
#     Graph Type: Violin plot
#     Interpretation: The below graph shows that the actual cost mostly of 20000, and the users are also using the mobiles which are at the cost mostly.

# %%
# Violin plot for RealCost
plt.figure(figsize=(5,3))
sns.violinplot(data=df, x='RealCost', palette='viridis')
plt.title("Violin Plot for RealCost", fontsize=12)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5416\3415666510.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='RealCost', palette='viridis')

# %% [markdown]
# 07. Column Name: Rating,
#     Graph Type: Histogram,
#     Description: Rating is nothing but the user will be showcasing their experience with mobile product.

# %%
# Histogram for Rating
plt.figure(figsize=(5,3))
sns.histplot(data=df, x='Rating', kde=True, color='orange', bins=15)
plt.title("Histogram for Rating", fontsize=12)
plt.show()

# %% [markdown]
# 08. Column Name: Brand,
#     Type of Graph: Count,
#     Description: So, in out dataset there are different type of brands avaliable for the mobiles. The below graph will analysis the number of people                      using specific type of brand. As we see, there are more then 80 peoples who are using the motorola brand mobiles.

# %%
# Count plot for Brand
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Brand', palette='bright')
plt.title("Count Plot for Brand", fontsize=12)
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5416\3946018236.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Brand', palette='bright')

# %% [markdown]
# 09. Column Name: Version,
#     Type of graph: Bar plot,
#     Description: Here we see is that, the verison T3 pro is used by number of peoples of different mobile brands.

# %%
# Bar plot for Version
plt.figure(figsize=(10,8))
version_counts = df['Version'].value_counts()
sns.barplot(x=version_counts.index, y=version_counts.values, palette='Set2')
plt.title("Bar Plot for Version", fontsize=14)
plt.xlabel("Categories")
plt.ylabel("Counts")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5680\621047818.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=version_counts.index, y=version_counts.values, palette='Set2')

# %% [markdown]
# 10. Column Name: Color,
#     Type of Graph: Pie plot,
#     Interpretation: The mobiles which are there in our dataset will be having different type of colors, this pie chat will analysis us the percentage of                     specific color existing in the dataset.

# %%
# Pie chart for Color
plt.figure(figsize=(10,8))
color_counts = df['Color'].value_counts()
plt.pie(color_counts, labels=color_counts.index, autopct='%.0f%%', colors=sns.color_palette('pastel'))
plt.title("Pie Chart for Different Colors", fontsize=14)
plt.show()

# %%
### Bivariate Analysis

# %% [markdown]
# Bivariate Analysis will be done on using multiple columns where we can easily understand the graphs and analyze the information in the data.
#
# Column Names: Brand, StarReview.
# Graph Type: Bar
# Description: The below data is graph between Continuous Vs Categorical where, continuous means the numerical data and Categorical means string data.
# I have plotted a bar graph using groupby where it takes Brand column as a categorical data and StarReview column as a Continuous. The graph shows us the Starreviews of each brand.

# %%
plt.figure(figsize = (8,6))
grouped_data = df.groupby('Brand')['StarReview'].mean().reset_index()
sns.barplot(x='Brand', y='StarReview', data=grouped_data, palette = 'Set2')
plt.title('Groupby: Continuous vs Categorical')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5416\1953319992.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Brand', y='StarReview', data=grouped_data, palette = 'Set2')

# %% [markdown]
# Column Names: DisplaySize (cm), Version, Brand.
# Graph Type: Pivot Table
# Description: The rows is the table having the types of mobile versions, the columns contains brand names and the values in the table are the mean value of the specific version and brand of the mobile.

# %%
pivot_data = df.pivot_table(values='DisplaySize (cm)', 
                            index='Version', 
                            columns='Brand', 
                            aggfunc='mean')

sns.heatmap(pivot_data, annot=True, cmap='Blues')
plt.title('Pivot Table: Continuous vs Categorical')
plt.show()

# %% [markdown]
# Description: A heatmap is a graphical representation of data where individual values are represented as colors in a matrix or grid. It is commonly used to visualize correlations, distributions, and patterns within a dataset.
#
# Column Names: StarReview, Reviews, RAM (GB)
# Graph Type: Corelation Heatmap
# Description: The rows and columns represent categories, variables, or indices of the data.
# Color Intensity: The intensity of the color reflects the magnitude of the data point.
# For example:
# --> Darker colors might represent higher values.
# --> Lighter colors might represent lower values.

# %%
# Correlation matrix
correlation_matrix = df[['StarReview', 'Reviews', 'RAM (GB)']].corr()

# Heatmap for correlation
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Plot: Continuous vs Continuous')
plt.show()

# %% [markdown]
# A crosstab (cross-tabulation) is a table that summarizes the relationship between two or more categorical variables. It displays the frequency (or count) of occurrences for combinations of values from the variables.
# The values in a crosstab are typically frequencies or aggregated values, such as:
# Counts: The number of occurrences for each combination of categories.
# Percentages: Proportions or percentages of the total dataset for each combination.
# Aggregations: If a numerical variable is involved, the crosstab can show sums, averages, or other statistics for each combination of categories.

# %%
# Crosstab between two categorical variables
crosstab_data = pd.crosstab(df['Brand'], df['Version'])

# Heatmap for crosstab data
sns.heatmap(crosstab_data, annot=True, cmap='Blues', fmt='d')
plt.title('Crosstab: Categorical vs Categorical')
plt.show()

# %% [markdown]
# Column Names: Brand, Cost.
# Graph Type: Bar
# Description: The below data is graph between Continuous Vs Categorical where, continuous means the numerical data and Categorical means string data.
# I have plotted a bar graph using groupby where it takes Brand column as a categorical data and Cost column as a Numerical. The graph shows us the Sales Cost of each brand lies.

# %%
plt.figure(figsize = (8,6))
grouped_data = df.groupby('Brand')['Cost'].mean().reset_index()
sns.barplot(x='Brand', y='Cost', data=grouped_data, palette = 'Set2')
plt.title('Groupby: Continuous vs Categorical')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5416\2713282102.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Brand', y='Cost', data=grouped_data, palette = 'Set2')

# %% [markdown]
# Coluumn Names: Rating, Reviews, ROM (GB)
# Graph Type: Corelation Heatmap
# Description: The rows and columns represent categories, variables, or indices of the data.
# Color Intensity: The intensity of the color reflects the magnitude of the data point.
# For example:
# --> Darker colors might represent higher values.
# --> Lighter colors might represent lower values.

# %%
correlation_matrix = df[['Rating', 'Reviews', 'ROM (GB)']].corr()

# Heatmap for correlation
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Plot: Continuous vs Continuous')
plt.show()

# %% [markdown]
# CONCLUSION:
#
# In this project mainly focused on extracting, cleaning, and visualizing data for various mobile products from the Flipkart website, offering a comprehensive understanding of the online mobile marketplace. The project demonstrated the potential of web scraping techniques in gathering real-time data, which is often inaccessible through traditional methods.
#
# During the data extractiai, we efficiently scraped key details such as product names, prices, ratings, and specifications. This unstructured data was then subjected to a thorough cleaning process, including handling missing lndu and , standardizing rmates to ensure accuracy and consistency. The resulting clean dataset was robust and ready for analysis.
#
# The visualization phase provided actionable insights into trends in mobile pricing, rating distributions, and feature comparisons. By leveraging Python libraries such as Matplotlib and Seaboi  we transformed raw data into meaningful visual representations. These visualizations revealed valuable patterns, such as the relationship between price and ratings, popular brands, and the availability of features in specific pice ,nges.
#
# Overall, this project highlighted the importance of integrating data science techniques to derive actionable insights from web data. It also emphasized the ethical considerations of web scraping and the need to respect website policies. The findings can assist buyers in making informed decisions and help sellers understand market trends.
